# %%
import sys
import time
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd()).parent))
from modules.spiral import spiral  # noqa
from modules.interpolate_points import interpolate_points  # noqa
from modules.dataset import Dataset
import pickle

# %%
# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (13, 5)

# %%
dataset_filepath = '../data/datasets'
X_full, y_full = Dataset.load(dataset_filepath).get_Xy()

# %%
plt.scatter(y_full[:,0], y_full[:,1], s=1, c='#00000006')

# %%
mask = (y_full[:,0]>-0.3) & (y_full[:,0]<0.3) & (y_full[:,1]>-0.4) & (y_full[:,1]<0.25)
X, y = X_full[mask], y_full[mask]
len(y)
# Out:
# 573670

# %%
plt.scatter(y[:,0], y[:,1], s=1, c='#00000006')

# %%
pickle.dump([X, y], open('../data/big-dataset.pickle', 'wb'))
